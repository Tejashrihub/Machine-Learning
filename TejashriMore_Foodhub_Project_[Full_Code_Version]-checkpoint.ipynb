# %% [markdown]
# # Project Python Foundations: FoodHub Data Analysis
#
# **Marks: 40**

# %% [markdown]
# ### Context
#
# The number of restaurants in New York is increasing day by day. Lots of students and busy professionals rely on those restaurants due to their hectic lifestyles. Online food delivery service is a great option for them. It provides them with good food from their favorite restaurants. A food aggregator company FoodHub offers access to multiple restaurants through a single smartphone app.
#
# The app allows the restaurants to receive a direct online order from a customer. The app assigns a delivery person from the company to pick up the order after it is confirmed by the restaurant. The delivery person then uses the map to reach the restaurant and waits for the food package. Once the food package is handed over to the delivery person, he/she confirms the pick-up in the app and travels to the customer's location to deliver the food. The delivery person confirms the drop-off in the app after delivering the food package to the customer. The customer can rate the order in the app. The food aggregator earns money by collecting a fixed margin of the delivery order from the restaurants.
#
# ### Objective
#
# The food aggregator company has stored the data of the different orders made by the registered customers in their online portal. They want to analyze the data to get a fair idea about the demand of different restaurants which will help them in enhancing their customer experience. Suppose you are hired as a Data Scientist in this company and the Data Science team has shared some of the key questions that need to be answered. Perform the data analysis to find answers to these questions that will help the company to improve the business.
#
# ### Data Description
#
# The data contains the different data related to a food order. The detailed data dictionary is given below.
#
# ### Data Dictionary
#
# * order_id: Unique ID of the order
# * customer_id: ID of the customer who ordered the food
# * restaurant_name: Name of the restaurant
# * cuisine_type: Cuisine ordered by the customer
# * cost: Cost of the order
# * day_of_the_week: Indicates whether the order is placed on a weekday or weekend (The weekday is from Monday to Friday and the weekend is Saturday and Sunday)
# * rating: Rating given by the customer out of 5
# * food_preparation_time: Time (in minutes) taken by the restaurant to prepare the food. This is calculated by taking the difference between the timestamps of the restaurant's order confirmation and the delivery person's pick-up confirmation.
# * delivery_time: Time (in minutes) taken by the delivery person to deliver the food package. This is calculated by taking the difference between the timestamps of the delivery person's pick-up confirmation and drop-off information

# %% [markdown]
# ### Let us start by importing the required libraries

# %%
# import libraries for data manipulation
import numpy as np
import pandas as pd

# import libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Understanding the structure of the data

# %%
# Read the data
df = pd.read_csv('foodhub_order.csv')  
# Returns the first 5 rows
df.head()
# df.tail() #returns the last 5 rows
# Out:
#    order_id  customer_id            restaurant_name cuisine_type  \
# 0   1477147       337525                    Hangawi       Korean
# 1   1477685       358141  Blue Ribbon Sushi Izakaya     Japanese
# 2   1477070        66393                Cafe Habana      Mexican
# 3   1477334       106968  Blue Ribbon Fried Chicken     American
# 4   1478249        76942           Dirty Bird to Go     American
#
#    cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 0              30.75         Weekend  Not given                     25
# 1              12.08         Weekend  Not given                     25
# 2              12.23         Weekday          5                     23
# 3              29.20         Weekend          3                     25
# 4              11.59         Weekday          4                     25
#
#    delivery_time
# 0             20
# 1             23
# 2             28
# 3             15
# 4             24

# %% [markdown]
# #### Observations:
#
# The DataFrame has 9 columns as mentioned in the Data Dictionary. Data in each row corresponds to the order placed by a customer.

# %% [markdown]
# ### **Question 1:** Write the code to check the shape of the dataset and write your observations based on that. (0.5 mark)

# %%
# Check the dimensionality of the DataFrame
df.shape
# Out:
# (1898, 9)

# %% [markdown]
# #### Observations:
# The DataFrame has 1898 rows and the 9 columns.Here we can see the dimensionality of the DataFrame.

# %% [markdown]
# ### Question 2: Write the observations based on the below output from the info() method. (0.5 mark)

# %%
# Check a concise summary of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1898 entries, 0 to 1897
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               1898 non-null   int64
#  1   customer_id            1898 non-null   int64
#  2   restaurant_name        1898 non-null   object
#  3   cuisine_type           1898 non-null   object
#  4   cost_of_the_order      1898 non-null   float64
#  5   day_of_the_week        1898 non-null   object
#  6   rating                 1898 non-null   object
#  7   food_preparation_time  1898 non-null   int64
#  8   delivery_time          1898 non-null   int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 133.6+ KB

# %% [markdown]
# #### Observations:
# * There are columns of different types in the DataFrame.
# * order_id,customer_id,food_preparation_time,delivery_time are an int type columns.
# * restaurant_name,cuisine_type,day_of_the_week,rating are object data type.
# * cost_of_the_order is a float type columns.
# * Total memory of Dataframe is 133.6+ KB

# %% [markdown]
# ### Question 3: 'restaurant_name', 'cuisine_type', 'day_of_the_week' are object types. Write the code to convert the mentioned features to 'category' and write your observations on the same. (0.5 mark)

# %%
# Create List of converting columns
col = ['restaurant_name', 'cuisine_type', 'day_of_the_week']
# Convert columns those mentioned into the list into categorical data
df[col] = df[col].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1898 entries, 0 to 1897
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               1898 non-null   int64
#  1   customer_id            1898 non-null   int64
#  2   restaurant_name        1898 non-null   category
#  3   cuisine_type           1898 non-null   category
#  4   cost_of_the_order      1898 non-null   float64
#  5   day_of_the_week        1898 non-null   category
#  6   rating                 1898 non-null   object
#  7   food_preparation_time  1898 non-null   int64
#  8   delivery_time          1898 non-null   int64
# dtypes: category(3), float64(1), int64(4), object(1)
# memory usage: 102.7+ KB

# %% [markdown]
# #### Observations:
# * The three columns Dtype object converted into the category Dtype.
# * This does not affect the way the DataFrame looks but reduces the memory usage significantly.
# * Coverting "objects" to "category" reduces the data space required to store the dataframe

# %% [markdown]
# ### **Question 4:** Write the code to find the summary statistics and write your observations based on that. (1 mark)

# %%
# Generate descriptive statistics of a DataFrame
df.describe()
# Out:
#            order_id    customer_id  cost_of_the_order  food_preparation_time  \
# count  1.898000e+03    1898.000000        1898.000000            1898.000000
# mean   1.477496e+06  171168.478398          16.498851              27.371970
# std    5.480497e+02  113698.139743           7.483812               4.632481
# min    1.476547e+06    1311.000000           4.470000              20.000000
# 25%    1.477021e+06   77787.750000          12.080000              23.000000
# 50%    1.477496e+06  128600.000000          14.140000              27.000000
# 75%    1.477970e+06  270525.000000          22.297500              31.000000
# max    1.478444e+06  405334.000000          35.410000              35.000000
#
#        delivery_time
# count    1898.000000
# mean       24.161749
# std         4.972637
# min        15.000000
# 25%        20.000000
# 50%        25.000000
# 75%        28.000000
# max        33.000000

# %% [markdown]
# #### Observations:
# * The order_id is in the same range just it varies values.
# * The customer_id has very huge difference from 1311 to 405334.
# * The cost_of_the_order varies from 4.47 to 35.41.
# * The food preparation time is from 20 minutes to 35 minutes. The delivery time varies from 15 minutes to 33 minutes.

# %% [markdown]
# ### **Question 5:** How many orders are not rated? (0.5 mark)

# %%
# Take rating column from DataFrame and by using value_counts() function count the no of each single rating which gives total count of each rating.
df['rating'].value_counts()
# Out:
# Not given    736
# 5            588
# 4            386
# 3            188
# Name: rating, dtype: int64

# %% [markdown]
# #### Observations:
# * In the DataFrame Out of 1898 orders Customer who gives rating 5 are 588.
# * Customer who gives rating 4 are 386.
# * Customer who gives rating 3 are 188.
# * Customer who didn't give rating are 736.

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# ### **Question 6:** Explore all the variables and provide observations on the distributions of all the relevant variables in the dataset. (5 marks)

# %%
# Calculate the Mean ,Median and Mode of the column cost_of_the_order
mean=df['cost_of_the_order'].mean()
median=df['cost_of_the_order'].median()
mode=df['cost_of_the_order'].mode()

# Print it by using print function
# The mode is the value that occurs most often.mode[0] returns the single value in the series instead of whole series.
print('The Mean is: ',mean,'\nThe Median is: ',median,'\nThe Mode is: ',mode[0])

# set the figure size
plt.figure(figsize=(10,5)) 

# Plot the histogram
plt.hist(df['cost_of_the_order'],bins=None,color='lightblue') 

# Draw lines on the plot for mean median and mode we have in cost_of_the_order column
plt.axvline(mean,color='green',label='Mean')    
plt.axvline(median,color='blue',label='Median')
plt.axvline(mode[0],color='red',label='Mode')

# label the x-axis
plt.xlabel('cost_of_the_order')

# label the y-axis
plt.ylabel('Frequency')

# Plot the legend
plt.legend()

# Display all figure/graph
plt.show()
# Out:
# The Mean is:  16.498851422550082
# The Median is:  14.14
# The Mode is:  12.18

# %% [markdown]
# #### Observations:
# - In this histogram we can see the minimum cost_of_the_order is 4.47 dollar and the maximum is 35.41 dollar
# * Most of the customer prefered to order the food of cost range between 12-16 dollar hence the frequency is high for this range
# * The histogram showing Mean,Median,Mode.The Mode is the data value that occurs most often in a data set which is 12.18.That means customers like to order food cost 12.18 dollar which is reasonable
# * The Median always located in the middle of Mode and Mean which is 14.14 and the Mean is 16.49
# * Frequency is going down after cost of the order 16 dollar means most of the customers don't like to order food cost more than 16-17 dollar

# %% [markdown]
# #### Order Id

# %%
# Check unique order ID
print('The unique order Ids are:',df.order_id.nunique())
# Out:
# The unique order Ids are: 1898

# %% [markdown]
# #### Observations:
# * In the dataframe all the order_id's are unique because all the customer has different order_id than each other.It can not repeat for another customer

# %% [markdown]
# #### Customer Id

# %%
# Check unique order Id
print('The unique customer Ids are:',df.customer_id.nunique())
# Out:
# The unique customer Ids are: 1200

# %% [markdown]
# #### Observations:
# In the DataFrame 1200 customer has unique customer ID means that does not have a duplicates.

# %%
#Check unique customer Id
df['customer_id'].value_counts().head()
# Out:
# 52832     13
# 47440     10
# 83287      9
# 250494     8
# 65009      7
# Name: customer_id, dtype: int64

# %% [markdown]
# ####  Observations:
# In the DataFrame there are various customers but these are the top 5 customers Id who ordered most frequently.

# %% [markdown]
# #### Restaurant Name

# %%
#Check unique restaurant name
print('The unique restaurants names are:\n',df.restaurant_name.unique())
# Out:
# The unique restaurants names are:
#  ['Hangawi', 'Blue Ribbon Sushi Izakaya', 'Cafe Habana', 'Blue Ribbon Fried Chicken', 'Dirty Bird to Go', ..., 'Rye House', 'Hiroko's Place', 'Frank Restaurant', 'Sarabeth's West', ''wichcraft']
# Length: 178
# Categories (178, object): ['Hangawi', 'Blue Ribbon Sushi Izakaya', 'Cafe Habana', 'Blue Ribbon Fried Chicken', ..., 'Hiroko's Place', 'Frank Restaurant', 'Sarabeth's West', ''wichcraft']

# %% [markdown]
# #### Observations:

# %% [markdown]
# In the dataframe total 178 restaurants and all restaurants are unique.

# %% [markdown]
# #### Cuisine Type

# %%
#Check unique cuisine type
print('The unique cuisine types are:\n',df.cuisine_type.unique())
# Out:
# The unique cuisine types are:
#  ['Korean', 'Japanese', 'Mexican', 'American', 'Indian', ..., 'Thai', 'Southern', 'French', 'Spanish', 'Vietnamese']
# Length: 14
# Categories (14, object): ['Korean', 'Japanese', 'Mexican', 'American', ..., 'Southern', 'French', 'Spanish', 'Vietnamese']

# %% [markdown]
# #### Observations:

# %% [markdown]
# In the dataframe there are total 14 unique cuisine types.The above function showing that cuisine type is a catagorical data type.

# %% [markdown]
# #### Cost of the order

# %%
# set the figure size
plt.figure(figsize=(10,5)) 
sns.histplot(data = df, x = 'cost_of_the_order');

# %% [markdown]
# #### Observations:

# %% [markdown]
# * In the DataFrame cost of the order is various from 4.47 dollar to 35.41 dollar
# * Customers mostly like to order food which is cost in range 12.18 to 12.23 dollar

# %% [markdown]
# #### Rating

# %%
plt.figure(figsize=(10,5)) 
sns.histplot(df['rating'], kde=True)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='Count'>

# %% [markdown]
# #### Observations:

# %% [markdown]
# * In the DataFrame total four types of rating.Most customers did'nt give rating
# * Around 600 customers gives rating 5.Some customers gives 4 and few customers gives rating 3

# %% [markdown]
# #### Food Preparation time

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data = df, x='food_preparation_time',palette = 'GnBu');
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# #### Observations:

# %% [markdown]
# * In the DataFrame the minimum food preparation time is 20 minutes and the maximum is 35 minutes.
# * We can observe from above graph that there are no extreme values / outliers.The data was equally distributed

# %% [markdown]
# ### Question 7: Write the code to find the top 5 restaurants that have received the highest number of orders. (1 mark)

# %%
print('Restaurants who recieved highest no of orders:\n',df.restaurant_name.value_counts())
# Out:
# Restaurants who recieved highest no of orders:
#  Shake Shack                  219
# The Meatball Shop            132
# Blue Ribbon Sushi            119
# Blue Ribbon Fried Chicken     96
# Parm                          68
#                             ...
# Klong                          1
# Kambi Ramen House              1
# Il Bambino                     1
# Hunan Manor                    1
# Lamarca Pasta                  1
# Name: restaurant_name, Length: 178, dtype: int64

# %% [markdown]
# #### Observations:

# %% [markdown]
# * In the dataframe total no of restaurants are 178 and the Shack Shack has received the highest no of orders which is 219
# * The Meatball shop is in the second position which recieved 132 orders
# * The Blue Ribbon Sushi is in the third position which recieved 119 orders
# * Blue Ribbon Fried Chicken is in the fourth position which recieved 96 orders
# * Parm is in the fifth position which recieved 68 orders

# %% [markdown]
# ### Question 8: Write the code to find the most popular cuisine on weekends. (1 mark)

# %%
# Create new variable MPC and compare day_of_the_week column to the columns value name weekend.
MPC=df[(df['day_of_the_week'] == 'Weekend')]
print('Most popular cuisine on weekends is:\n',MPC.cuisine_type.describe())
# Out:
# Most popular cuisine on weekends is:
#  count         1351
# unique          14
# top       American
# freq           415
# Name: cuisine_type, dtype: object

# %% [markdown]
# #### Observations:
# * In the DataFrame 1351 customers ordered on weekends from various cuisines but most of the customers ordered from American cuisine
# * The total orders from American cuisines are 415 on weekends.There are total 14 types of cuisines in the DataFrame

# %% [markdown]
# ### Question 9: Write the code to find the number of total orders where the cost is above 20 dollars. What is the percentage of such orders in the dataset?  (1 mark)

# %%
# Create new variable TA which stores cost_of_the_order greater than 20 dollar
TA=df[(df['cost_of_the_order']> 20)].shape[0]
print('The number of total orders that cost above 20 dollars is:',TA)

# No of orders cost greater than 20 divided by total orders and multiply by 100 to get percentage 
Percentage = (TA / df.shape[0] )* 100
print("Percentage of orders above 20 dollars is:",Percentage)
# Out:
# The number of total orders that cost above 20 dollars is: 555
# Percentage of orders above 20 dollars is: 29.24130663856691

# %% [markdown]
# #### Observations:
# * In the dataframe out of 1898 orders 555 orders has cost above 20 dollar
# * The percentage of orders above 20 dollars is 29.24.

# %% [markdown]
# ### Question 10: Write the code to find the mean delivery time based on this dataset. (1 mark)

# %%
# Use mean function to the column
MDT=df['delivery_time'].mean()
print('The mean delivery time based on this dataset is:',MDT)
# Out:
# The mean delivery time based on this dataset is: 24.161749209694417

# %% [markdown]
# #### Observations:
# * In the dataframe there are various columns and the mean of the column delivery time is 24.16

# %% [markdown]
# ### Question 11: Suppose the company has decided to give a free coupon of 15 dollars to the customer who has spent the maximum amount on a single order. Write the code to find the ID of the customer along with the order details. (1 mark)

# %%
#Select the cost_of_the_order from the DataFrame and compaire it with same column by using max() function to get maximum amount
df[df['cost_of_the_order'] == df['cost_of_the_order'].max()]
# Out:
#      order_id  customer_id restaurant_name   cuisine_type  cost_of_the_order  \
# 573   1477814        62359           Pylos  Mediterranean              35.41
#
#     day_of_the_week rating  food_preparation_time  delivery_time
# 573         Weekday      4                     21             29

# %% [markdown]
# #### Observations:

# %% [markdown]
# * In this dataframe the highest no of order_cost is 35.41 dollar and only one customer applicable for free coupon offer
# * Id of the customer is 62359 and the order Id is 1477814.The order is from Pylos restaurant which is Mediterranean and this order placed on weekday

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# ### Question 12: Perform bivariate analysis to explore relationships between the important variables in the dataset. (7 marks)

# %% [markdown]
# #### Cuisine Type vs Delivery Time

# %%
# Set the figure size
plt.figure(figsize=(10,5))
sns.boxplot(data = df, x='cuisine_type',y='delivery_time',palette = 'OrRd');
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### Observations:

# %% [markdown]
# * In the DataFrame various types of cuisine and the delivery time is vary for each cuisine
# * Delivery time of each cuisine is minimum 15 minutes and maximum 33 minutes
# * Korean cuisine took very less time and the Vietnamese took long time to deliver the food
# * In the DataFrame most of the cuisine took 24 minutes to food delivery and very less to took more than 30 minutes to delivery

# %% [markdown]
# ####  Day of the week vs Delivery Time

# %%
# Set a figure size and Create a barplot
plt.figure(figsize=(10,5))
sns.barplot(data = df, x = 'day_of_the_week', y = 'delivery_time',palette = 'mako_r');

# %% [markdown]
# #### Observations:

# %% [markdown]
# * In the DataFrame ration between day_of_the_week and the delivery_time is vary
# * Most of the customers like to order food at home on the weekdays so the weekdays bar is higher than weekends bar
# * On the weekends customers like to take dine in so the frequency is less compared to weekdays

# %% [markdown]
# #### Cusine Type vs Cost of the order

# %%
# Set a figure size and Create a barplot 
plt.figure(figsize=(25,9))
sns.barplot(data = df, x='cuisine_type',y='cost_of_the_order',hue='rating',palette='tab20_r');

# Rotate the x-axis's labels by 90 degree
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### Observations:

# %% [markdown]
# * In the DataFrame total 14 types of cuisine.Cost_of_the _order is vary from cuisine to cuisine
# * Most of the customers don't like to give rating to cuisine
# * Spanish and Thai cuisine's don't have rating three

# %% [markdown]
# #### Rating vs Cost of the order

# %%
# Create a pointplot
plt.figure(figsize=(10, 5))
sns.pointplot(data=df,x='rating',y='cost_of_the_order')
plt.show()

# %% [markdown]
# #### Observations:

# %% [markdown]
# * In the DataFrame most of the customers like to give rating 3 when the cost_of_the_order is vary
# * Customer gives rating 4 and 5 when the cost_of_the_order increases
# * It seems when the cost_of_the_order increases then customer's rating is also increases

# %% [markdown]
# #### Rating vs Food preparation Time

# %%
# Create a pointplot
plt.figure(figsize=(10, 5))
sns.pointplot(data = df, x='rating',y='food_preparation_time');

# %% [markdown]
# #### Observation:

# %% [markdown]
# * In the above pointplot we can see very little changes in line which connected points
# * In the DataFrame the food_preparation_time is constant it goes upward little bit

# %% [markdown]
# #### Correlation among variables

# %%
# Create a heatmap
fig,ax = plt.subplots(figsize=(10, 10))   
sns.heatmap(df.corr(), ax=ax, annot=True, linewidths=0.05, fmt= '.2f',cmap="PiYG_r")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Observations:

# %% [markdown]
# * In the DataFrame the correlation between the variables cost_of_the_order and the foodhub_charges is postive and they are positively correlated because it is close to 1
# * Same for the variables food_preparation_time and total_delivery_time.That is as one increases so does the other
# * Most of the other variables values closer to zero so,there is no linear trend between the two variables
# * Some of them is -1 means instead of both increasing one variable will decrease as the other increases
# * Diagonals who are all 1.00 or dark pink in color those squares are correlating each variable to itself

# %%
# Determine skewness of data
df.skew()
# Out:
# order_id                 0.000000
# customer_id              0.665041
# cost_of_the_order        0.621747
# food_preparation_time    0.036469
# delivery_time           -0.236536
# dtype: float64

# %% [markdown]
# #### Observations:

# %% [markdown]
# * In the DataFrame delivery_time has negative value so data are skewed left and the left tail is long relative to the right tail

# %% [markdown]
# ### Multivariate Analysis

# %%
# Create a pairplot
sns.pairplot(df)

# %% [markdown]
# #### Observations:

# %% [markdown]
# * In the above plot scatter diagrams are plotted for all the numerical columns in the dataset. A scatter plot is a visual representation of the degree of correlation between any two columns
# * In the above diagram we can see perfect correlation between same columns

# %%
# Create a scatterplot
plt.figure(figsize=(10, 5))
sns.scatterplot(data=df, x="cost_of_the_order", y="food_preparation_time")
# Out:
# <AxesSubplot:xlabel='cost_of_the_order', ylabel='food_preparation_time'>

# %% [markdown]
# #### Observations:

# %% [markdown]
# * In the above scatterplot there is gap between cost of the order and the food preparation time i.e 25-28
# * We can see here the visual information about the degree of correlation
# * The minimum cost of the order is 4.47,no less than it

# %% [markdown]
# ### Question 13: Suppose the company wants to provide a promotional offer in the advertisement of the restaurants. The condition to get the offer is that the restaurants must have a rating count of more than 50 and the average rating should be greater than 4. Write the code to find the restaurants fulfilling the criteria to get the promotional offer. (2 marks)

# %%
# Filter the rated restaurants
Rate=df[df['rating']!= 'Not given'].copy()

# Convert rating column from object to integer
Rate['rating']=Rate['rating'].astype('int')

# Use groupby for restaurant_name and rating variables
Promo_offer=Rate.groupby(['restaurant_name'])['rating'].count().sort_values(ascending=False).reset_index()
Promo_offer.head()
# Out:
#              restaurant_name  rating
# 0                Shake Shack     133
# 1          The Meatball Shop      84
# 2          Blue Ribbon Sushi      73
# 3  Blue Ribbon Fried Chicken      64
# 4           RedFarm Broadway      41

# %% [markdown]
# #### Observations:

# %% [markdown]
# * In the DataFrame Shake Shack restaurant get highest rating count which is 133
# * It shows total 5 restaurants who got rating count more than 50
# * These restaurants fulfilling the criteria and get promotional offer

# %% [markdown]
# ### Question 14: Suppose the company charges the restaurant 25% on the orders having cost greater than 20 dollars and 15% on the orders having cost greater than 5 dollars. Write the code to find the net revenue generated on all the orders given in the dataset. (2 marks)

# %%
# Creat new column and give condition
df['foodhub_charges'] =  [order_cost * 0.25 if order_cost > 20 else
                        order_cost * 0.15 if order_cost > 5 else
                        0
                        for order_cost in df['cost_of_the_order']] 

total_rev = df['foodhub_charges'].sum()
total_rev
print('The net revenue is:',total_rev ,'dollars')
# Out:
# The net revenue is: 6166.303 dollars

# %% [markdown]
# #### Observations:

# %% [markdown]
# * Total revenue generated on all orders given in Dataset is 6166.303 dollars

# %% [markdown]
# ### Question 15: Suppose the company wants to analyze the total time required to deliver the food. Write the code to find out the percentage of orders that have more than 60 minutes of total delivery time. (2 marks)
#
# Note: The total delivery time is the summation of the food preparation time and delivery time.

# %%
# Create new coloumn and Calculate the total delivery time
df['total_delivery_time'] = df['food_preparation_time'] + df['delivery_time']

# Give condition TDT greater than 60
TDT=df[(df['total_delivery_time']> 60)].shape[0]
print('The number of orders that have more than 60 minutes is:',TDT)

# TDT more than 60 minutes counts divided by all delivery time and multiply it by 100
Percentage = (TDT / df.shape[0] )* 100
print("The Percentage of orders that have more than 60 minutes:",Percentage)
# Out:
# The number of orders that have more than 60 minutes is: 200
# The Percentage of orders that have more than 60 minutes: 10.537407797681771

# %% [markdown]
# #### Observations:

# %% [markdown]
# * In the DataFrame the no of orders that take more than 60 minutes to total delivery are 200
# * Percentage of those orders are 10.53%

# %% [markdown]
# ### Question 16: Suppose the company wants to analyze the delivery time of the orders on weekdays and weekends. Write the code to find the mean delivery time on weekdays and weekends. Write your observations on the results. (2 marks)

# %%
# Creat new variable and compaire coloumn to the condition,use the mean function to get mean value
Weekday=df[(df['day_of_the_week'] == 'Weekday')]['delivery_time'].mean()
print('The mean delivery time on weekdays is:',Weekday,'minutes')

Weekend=df[(df['day_of_the_week'] == 'Weekend')]['delivery_time'].mean()
print('The mean delivery time on weekends is:',Weekend,'minutes')
# Out:
# The mean delivery time on weekdays is: 28.340036563071298 minutes
# The mean delivery time on weekends is: 22.4700222057735 minutes

# %% [markdown]
# #### Observations:

# %% [markdown]
# * In the DataFrame the mean delivery time on weekdays is 28.34 minutes
# * Compaired with weekdays the mean time of weekends is less because at the weekends the food order rate is low

# %% [markdown]
# ### Conclusion and Recommendations

# %% [markdown]
# ### **Question 17:** Write the conclusions and business recommendations derived from the analysis. (3 marks)

# %% [markdown]
# #### Conclusion
# I analyzed a dataset of nearly 2000k orders from the various restaurants by Foodhub app, in New York city. The data spanned every day when the customer order the food from the restaurants by using Foodhub app.The main feature of interest here is the number of orders.Each customer has assigned by customer ID.The no of orders from the restaurants are depends on the day of the week and the food preparation time and the delivery time.I determined the total delivery time and the factors that affect online orders.I also determined companies promotional offer by using customer's rating.
#
#
# I have been able to conclude that
#
# * Out of 1898 orders Customer who didn't give rating are 736.
# * Food preparation time do not have much impact on the number of orders and ratings.
# * The delivery time of the food is higher on the weekdays as compared to weekends.
# * It is encouraging to see that New Yorkers mostly like American cuisines.
# * Customers like to order most reasonable food cost of 12-13 dollars.
# * I'm able to find top 5 restaurants in the Foodhub app.
# * Customers gives rating 5 when the cost of the order is higher.
#
# #### Recommendation to business
#
# * American Cuisines are the most popular in New york city.Foodhub app should add more american cuisines.
# * Delivery time decreases on weekends,customers like to take Dine-In on weekends.Foodhub should give discount on weekends.
# * Procure more data on price and build a model that can predict optimal pricing.
# * The Restaurants who recieved highest no of orders are Shake Shack,The Meatball shop,Blue Ribbon Sushi,Blue Ribbon Fried       Chicken,Parm rest of them should use promotions or other deals to increase customers.
# * Foodhub can combine food preparation time and delivery time to the total delivery time.
# * Foodhub can use customers data to adjust delivery radius and it will also help to find which delivery areas are the most profitable.
